# %%
from google.colab import drive
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CarolineNB/nyc-collision-dataset-csv/master/aiddata-countries-only%20-%20aiddata-countries-only.csv")
df
# Out:
#        Unnamed: 0  ...                   coalesced_purpose_name
# 0               1  ...       Power generation/renewable sources
# 1               2  ...    Electrical transmission/ distribution
# 2               3  ...                           Rail transport
# 3               4  ...                           Rail transport
# 4               5  ...                          Water transport
# ...           ...  ...                                      ...
# 98535       98536  ...                         Higher education
# 98536       98537  ...  Material relief assistance and services
# 98537       98538  ...                         Higher education
# 98538       98539  ...                 Social/ welfare services
# 98539       98540  ...        Education facilities and training
#
# [98540 rows x 9 columns]

# %%
donors = df.groupby('donor')['commitment_amount_usd_constant'].sum()
recipients = df.groupby('recipient')['commitment_amount_usd_constant'].sum()

# %%
result = donors - recipients
result = result.sort_values()
result
# Out:
# Thailand               -4.904129e+10
# Brazil                 -3.660612e+10
# Colombia               -2.553035e+10
# Poland                 -2.451682e+10
# Korea                  -2.399528e+10
# Chile                  -7.333565e+09
# Kuwait                 -6.402462e+09
# Taiwan                 -3.315817e+09
# Saudi Arabia           -3.179338e+09
# Hungary                -2.925003e+09
# Czech Republic         -2.132983e+09
# Cyprus                 -9.681493e+08
# Slovak Republic        -8.208000e+08
# Ireland                -6.394943e+08
# Qatar                  -6.292647e+08
# Greece                 -4.867107e+08
# Luxembourg             -4.434858e+08
# Estonia                -2.510706e+08
# United Arab Emirates   -2.325695e+08
# Slovenia               -2.252852e+08
# New Zealand            -1.688384e+08
# Australia              -1.260019e+08
# Portugal               -1.063417e+08
# Iceland                -1.788754e+07
# Liechtenstein          -1.402238e+07
# ...

# %%
rows_Nan = result.isnull()
were_nan = recipients[rows_Nan] * -1

# %%
final_results = result.append(were_nan).dropna()

# %%
ordered_results = final_results.sort_values(ascending=False)

# %%
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
ordered_results.to_csv('data.csv')
# !cp data.csv "drive/My Drive/2018-2022 (College)/Second Year (2019-2020)/Infovis"
