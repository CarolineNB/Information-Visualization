# %%
from google.colab import drive
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CarolineNB/nyc-collision-dataset-csv/master/aiddata-countries-only%20-%20aiddata-countries-only.csv")

# %%
donors = df.groupby('donor')['commitment_amount_usd_constant'].sum()
recipients = df.groupby('recipient')['commitment_amount_usd_constant'].sum()

# %%
total_assets = donors + recipients

# %%
total_ratio = donors / total_assets

# %%
final_ratio = total_ratio.sort_values().fillna(0) #those with NaNs are countries that have only recieved 
final = pd.DataFrame(final_ratio)
final['total'] = total_assets
final
# Out:
#                       commitment_amount_usd_constant         total
# Thailand                                5.191742e-07  4.904134e+10
# Cyprus                                  5.783132e-06  9.681605e+08
# Colombia                                7.473152e-06  2.553073e+10
# Poland                                  1.644466e-05  2.451763e+10
# Brazil                                  3.098852e-05  3.660839e+10
# Chile                                   7.694241e-05  7.334693e+09
# Hungary                                 1.109332e-04  2.925652e+09
# Slovak Republic                         4.814730e-04  8.215912e+08
# Slovenia                                6.650613e-04  2.255852e+08
# Estonia                                 1.108547e-03  2.516284e+08
# Czech Republic                          4.152061e-03  2.150844e+09
# Iceland                                 9.461158e-03  1.823255e+07
# Taiwan                                  2.403976e-02  3.483292e+09
# ...

# %%
drive.mount('drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at drive

# %%
final.to_csv('vis2Data.csv')
# !cp vis2Data.csv "drive/My Drive/2018-2022 (College)/Second Year (2019-2020)/Infovis"
